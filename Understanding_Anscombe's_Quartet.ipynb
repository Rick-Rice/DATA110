# %% [markdown]
# <a href="https://colab.research.google.com/github/Rick-Rice/DATA110/blob/main/Understanding_Anscombe's_Quartet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# ## Understanding Anscombe's Quartet
#
# **Anscombe's Quartet** consists of multiple datasets, each comprising (x, y) pairs. These datasets are unique in that they share several statistical properties:
#
# - **Mean**: The average value of the datasets is consistent across both x and y components.
# - **Standard Deviation**: Measures of how data points are dispersed in the dataset remain constant.
# - **Regression Line**: Linear regressions drawn from these datasets tend to follow the same line.
#
# However, despite these similarities in basic statistical metrics, each dataset in the quartet tells a different story when plotted graphically. They exhibit distinct patterns and relationships between the x and y variables.
#
# ### The Significance of Anscombe's Quartet
#
# The primary lesson of **Anscombe's Quartet** is twofold:
#
# 1. **Visual Analysis**: It highlights the critical importance of visually inspecting your data. Graphical representations can uncover underlying patterns, trends, and outliers that summary statistics might miss.
#
# 2. **Beyond Statistics**: While statistical measures are invaluable, relying solely on them can be deceptive. The quartet demonstrates that datasets with identical statistical properties can indeed have drastically different distributions and relationships.
#
# Anscombe's Quartet is a powerful reminder that in data analysis, the true essence and story of the data often lie beyond mere numbers and summary statistics.
#
# ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %% [markdown]
# ## Task1:
#  Run the code below and check if all these graph look different.

# %%
ys=[y1,y2,y3,y4]
titles=['Plot 1','Plot 2','Plot 3','Plot 4']
colors=['r','g','b','y']
fig, axs =plt.subplots(2,2,figsize=(10,10))

for i, ax in enumerate(axs.flat):
  ax.scatter(x,ys[i],color=colors[i])
  ax.set_title(titles[i])

# %% [markdown]
# ## Task2:
# Run the code below and find the statisical information about the dataset y1

# %%
# Convert the list y1 into a Pandas Series object. This allows us to use powerful data analysis tools provided by Pandas on the dataset.
y1_series = pd.Series(y1)

# Generate descriptive statistics of the y1 series. This includes count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile), 75th percentile (Q3), and maximum.
# It provides a quick overview of the central tendency, dispersion, and shape of the dataset's distribution.
y1_description = y1_series.describe()

# Print the descriptive statistics to the console. This output can be used to quickly understand the statistical characteristics of the data in y1.
print(y1_description)
# Out:
# count    11.000000
# mean      7.500909
# std       2.031568
# min       4.260000
# 25%       6.315000
# 50%       7.580000
# 75%       8.570000
# max      10.840000
# dtype: float64

# %% [markdown]
# ## Task 3:
# Replicate Analysis for Additional Datasets You've successfully completed the descriptive analysis for the dataset `y1`. Now, apply the same process to analyze the additional datasets: `y2`, `y3`, and `y4`.
#
# For each dataset (`y2`, `y3`, and `y4`). and Print the result using `print` function.

# %%
## your code for Task 3 should be here

# FOR Y2
print('For y2: \n')

# Convert the list y2 into a Pandas Series object. This allows us to use powerful data analysis tools provided by Pandas on the dataset.
y2_series = pd.Series(y2)

# Generate descriptive statistics of the y2 series. This includes count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile), 75th percentile (Q3), and maximum.
# It provides a quick overview of the central tendency, dispersion, and shape of the dataset's distribution.
y2_description = y2_series.describe()

# Print the descriptive statistics to the console. This output can be used to quickly understand the statistical characteristics of the data in y1.
print(y2_description)


# FOR Y3

print('\nFor y3: \n')

# Convert the list y3 into a Pandas Series object. This allows us to use powerful data analysis tools provided by Pandas on the dataset.
y3_series = pd.Series(y3)

# Generate descriptive statistics of the y3 series. This includes count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile), 75th percentile (Q3), and maximum.
# It provides a quick overview of the central tendency, dispersion, and shape of the dataset's distribution.
y3_description = y3_series.describe()

# Print the descriptive statistics to the console. This output can be used to quickly understand the statistical characteristics of the data in y1.
print(y3_description)


# FOR Y4

print('\nFor y4: \n')

# Convert the list y4 into a Pandas Series object. This allows us to use powerful data analysis tools provided by Pandas on the dataset.
y4_series = pd.Series(y4)

# Generate descriptive statistics of the y1 series. This includes count, mean, standard deviation, minimum, 25th percentile (Q1), median (50th percentile), 75th percentile (Q3), and maximum.
# It provides a quick overview of the central tendency, dispersion, and shape of the dataset's distribution.
y4_description = y4_series.describe()

# Print the descriptive statistics to the console. This output can be used to quickly understand the statistical characteristics of the data in y1.
print(y4_description)
# Out:
# For y2:
#
# count    11.000000
# mean      7.500909
# std       2.031657
# min       3.100000
# 25%       6.695000
# 50%       8.140000
# 75%       8.950000
# max       9.260000
# dtype: float64
#
# For y3:
#
# count    11.000000
# mean      7.500000
# std       2.030424
# min       5.390000
# 25%       6.250000
# 50%       7.110000
# 75%       7.980000
# max      12.740000
# dtype: float64
#
# For y4:
#
# count    11.000000
# mean      7.500909
# std       2.030579
# min       5.250000
# 25%       6.170000
# 50%       7.040000
# 75%       8.190000
# max      12.500000
# dtype: float64

# %% [markdown]
# ---
#
# ## Task 4: Reflection and Comparative Analysis
#
# Having computed the descriptive statistics for each of the datasets (`y1`, `y2`, `y3`, and `y4`), it's now time to reflect on your findings and conduct a comparative analysis.
#
# **Objectives:**
#
# - Understand the implications of the statistical summaries.
# - Identify any underlying patterns or anomalies across the datasets.
# - Relate your observations to the principles highlighted by Anscombe's quartet.
#
# **Instructions:**
#
# 1. **Summarize Your Observations:**
#     - Begin by summarizing the descriptive statistics for each dataset. Highlight any notable similarities or differences in terms of mean, standard deviation, quartiles, and range.
#
# 3. **Analytical Reflection:**
#     - Discuss how the datasets compare to each other. Are there any datasets that appear statistically similar but differ significantly when visualized?
#     - Reflect on how Anscombe's quartet demonstrates the importance of both statistical analysis and data visualization in understanding data.
#
# 4. **Concluding Thoughts:**
#     - Conclude by discussing the significance of descriptive statistics and data visualization in data analysis.
#     - Mention any insights or lessons learned from this exercise about the potential pitfalls of relying solely on numerical summaries to

# %% [markdown]
# ---------

# %% [markdown]
# ### Task 4 Submission
#
# Please provide your comprehensive answer for Task 4 here. Ensure your response is well-structured and utilizes Markdown formatting for clarity and organization.

# %% [markdown]
# ## Task 4 - Reflection and Comparative Analysis
#
# Big picture, just because the descriptive statistics (mean, standard deviation, etc.) for a couple of sets of data are similar, that doesn't necessarily mean, in a practical sense, that they are similar.  Visual inspection of a simple scatter chart may impress upon even the casual observer that they are entirely different!
#
# **Observations**
#
# My first observation is that Plot 4 is wrong.  In the traditional presentation of Anscombe's Quartet, Plot 4 would have all points linedup over the 8 on the x-axis -- with one stray point elsewhere.  I believe that was intended here (x4 was initialized but not used), but due to a coding oversight, Plot 4 was non-traditional.  An example of the corrected code is given below.
#
# To three significant digits (Anscombe [1973] was probably using a slide-rule), the mean and standard deviation are the same for the four data sets.  The range is the same for the y values, also.  However, when one looks at the plots, it is apparent for plots three and four that the high y value might legitimately be considered an outlier.
#
# The Task 2 and 3 coding considers only the y-axis values.  We woud expect the mean and second quartile values to be the same if we have a normal distribution.  For Plot 1, the mean and Q2 values are close, but for the other three we would have to assume a skewed distribution.  Q2 for Plot 2 is more than the mean.  Q2 for Plots 3 & 4 are less than the mean.  These disparities are the first clue (without looking at the plots) that these data sets may be quite dissimilar.  These observations are confirmed by the Q1 and Q3 data.
#
#
# **Analytical Reflection**
#
# Statistically, all four data sets look similar.  They are distinguished by their quartile data, but even Plots 3 and 4 are very similar in terms of quartile data.  One has to look at the x-axis data, in addition to the y-axis data, for the difference between Plots 3 and 4 to stand out:  Plot 4 has ten identical x-axis values.  Using the non-traditional Plot 4, even this distinction vanishes:  It is the order of the data pairs that seems to form a perfect line (with an outlier) for Plot 3 but not Plot 4.  All four plots have a distinctive morphology when visualized.
#
# Anscombe's 1973 paper begins, "Graphs are essential to good statisical analysis."  His famous Quartet makes that statement ring true.  Statistical analysis is essential for exactness in applications such as regression analysis, used even more now than in Anscombe's time, for all kinds of data science projects from forecasting to pattern recognition. Nevertheless, a great deal of meaning is liable to be lost without graphical representation.
#
#
# **Concluding Thoughts**
#
# It seems to this writer that it is essential to know whether you have a normal distribution (or something that appoximates a normal distribution).  In that case, a mean and standard distribution should be enough to create a graph -- on a computer or simply in your mind's eye -- of the distribution.  Otherwise, descriptive statistics are putting you in a situation very much like the blind men and the elephant:
#
# ![image.png](data:image/png;base64,...)
#
# Which blind man you are depends on which descriptive statistic you are considering.  Better you should just unblind yourself and plot the data.
#
# Again citing Frank Anscombe (1973, *The American Statistician*, Volume 27, Issue 1), "Few of us escape being indocrinated with these notions ... actually looking at the data is cheating."  This is so true!  The Anscombe Quartet really drives home the point that data visualization can be essential.  It also makes the point (e.g. Plot 4) that is important to look at all the data, from both dependent *and* independent variables.

# %%
# Corrected version of Anscombe's Quartet plot
#
# Note that the variable xs is initialized and,
# in the for-loop, xs (replacing x) is now indexed.

x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
xs = [x,x,x,x4]
ys=[y1,y2,y3,y4]
titles=['Plot 1','Plot 2','Plot 3','Plot 4']
colors=['r','g','b','y']
fig, axs =plt.subplots(2,2,figsize=(10,10))

for i, ax in enumerate(axs.flat):
  ax.scatter(xs[i],ys[i],color=colors[i])
  ax.set_title(titles[i])
