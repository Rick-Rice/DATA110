# %% [markdown]
# <a href="https://colab.research.google.com/github/Rick-Rice/DATA110/blob/main/Project_1_Global_Corruption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1 - Global Corruption
#
# Using data from Transparency International
#
# Rick Rice, March 20, 2024

# %% [markdown]
# ### Load 2021-2022 data

# %%
import pandas as pd

corruption_file2 = '/content/CPI2022_GlobalResultsTrends.csv'
df = pd.read_csv(corruption_file2,header=2,index_col='Country')

df.head()
# Out:
#                      ISO3 Region  CPI score 2022  Rank 2022  Sources 2022  \
# Country
# Afghanistan           AFG     AP            24.0      150.0           4.0
# Albania               ALB    ECA            36.0      101.0           8.0
# United Arab Emirates  ARE   MENA            67.0       27.0           7.0
# Angola                AGO    SSA            33.0      116.0           7.0
# Argentina             ARG    AME            38.0       94.0           7.0
#
#                       ...  Sources 2013  Standard error 2013  CPI Score 2012  \
# Country               ...
# Afghanistan           ...           3.0                  3.3             8.0
# Albania               ...           7.0                  2.1            33.0
# United Arab Emirates  ...           7.0                  4.7            68.0
# Angola                ...           7.0                  2.8            22.0
# Argentina             ...           8.0                  2.4            35.0
#
# ...

# %%
df.shape
# Out:
# (181, 41)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# DataFrame with only CPI scores

df_CPI = df.iloc[:,[2,6,10,14,18,22,26,29,32,35,38]]

df_CPI.head()
# Out:
#                       CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# Afghanistan                     24.0            16.0            19.0
# Albania                         36.0            35.0            36.0
# United Arab Emirates            67.0            69.0            71.0
# Angola                          33.0            29.0            27.0
# Argentina                       38.0            38.0            42.0
#
#                       CPI score 2019  CPI score 2018  CPI score 2017  \
# Country
# Afghanistan                     16.0            16.0            15.0
# Albania                         35.0            36.0            38.0
# United Arab Emirates            71.0            70.0            71.0
# Angola                          26.0            19.0            19.0
# Argentina                       45.0            40.0            39.0
#
#                       CPI score 2016  CPI score 2015  CPI score 2014  \
# Country
# ...

# %%
# Create transpose because it plots better that way

dfT_CPI = df_CPI.transpose()

dfT_CPI.head()
# Out:
# Country         Afghanistan  Albania  United Arab Emirates  Angola  Argentina  \
# CPI score 2022         24.0     36.0                  67.0    33.0       38.0
# CPI score 2021         16.0     35.0                  69.0    29.0       38.0
# CPI score 2020         19.0     36.0                  71.0    27.0       42.0
# CPI score 2019         16.0     35.0                  71.0    26.0       45.0
# CPI score 2018         16.0     36.0                  70.0    19.0       40.0
#
# Country         Armenia  Australia  Austria  Azerbaijan  Bahamas  ...  \
# CPI score 2022     46.0       75.0     71.0        23.0     64.0  ...
# CPI score 2021     49.0       73.0     74.0        30.0     64.0  ...
# CPI score 2020     49.0       77.0     76.0        30.0     63.0  ...
# CPI score 2019     42.0       77.0     77.0        30.0     64.0  ...
# CPI score 2018     35.0       77.0     76.0        25.0     65.0  ...
#
# ...

# %%
dfT_CPI.shape
# Out:
# (11, 181)

# %%
#  Exploratory data analysis - plot every CPI score for every country

plt.figure(figsize=(18,14))

sns.lineplot(data=dfT_CPI).set(title='Corruption Perception Index')

plt.legend(ncols=7,fontsize='small',bbox_to_anchor=(0.96,-0.1))

plt.show()

# %% [markdown]
# ## Average CPI by Region

# %%
# Create dataframe with region as well as CPI scores

dfR_CPI = df.iloc[:,[1,2,6,10,14,18,22,26,29,32,35,38]]

dfR_CPI.head()
# Out:
#                      Region  CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# Afghanistan              AP            24.0            16.0            19.0
# Albania                 ECA            36.0            35.0            36.0
# United Arab Emirates   MENA            67.0            69.0            71.0
# Angola                  SSA            33.0            29.0            27.0
# Argentina               AME            38.0            38.0            42.0
#
#                       CPI score 2019  CPI score 2018  CPI score 2017  \
# Country
# Afghanistan                     16.0            16.0            15.0
# Albania                         35.0            36.0            38.0
# United Arab Emirates            71.0            70.0            71.0
# Angola                          26.0            19.0            19.0
# Argentina                       45.0            40.0            39.0
#
#                       CPI score 2016  CPI score 2015  CPI score 2014  \
# ...

# %%
#  What are the regions?

regions = []

regions = dfR_CPI['Region'].unique()

print(regions)
# Out:
# ['AP' 'ECA' 'MENA' 'SSA' 'AME' 'WE/EU']

# %%
#  Separate dataframe for each region.  (Another approach is used below using groupby)

df_AP  = dfR_CPI[ dfR_CPI['Region']=='AP' ]

df_ECA = dfR_CPI[ dfR_CPI['Region']=='ECA' ]

df_MENA = dfR_CPI[ dfR_CPI['Region']=='MENA' ]

df_SSA = dfR_CPI[ dfR_CPI['Region']=='SSA' ]

df_AME = dfR_CPI[ dfR_CPI['Region']=='AME' ]

df_EU = dfR_CPI[ dfR_CPI['Region']=='WE/EU' ]

# %%
# Average CPI scores for each region

#df_regions = pd.DataFrame().reindex_like(df_CPI)

df_regions = df_CPI.iloc[:0,:].copy()

df_regions.loc['Asia Pacific'] = [   df_AP['CPI score 2022'].mean(),
                           df_AP['CPI score 2021'].mean(),
                           df_AP['CPI score 2020'].mean(),
                           df_AP['CPI score 2019'].mean(),
                           df_AP['CPI score 2018'].mean(),
                           df_AP['CPI score 2017'].mean(),
                           df_AP['CPI score 2016'].mean(),
                           df_AP['CPI score 2015'].mean(),
                           df_AP['CPI score 2014'].mean(),
                           df_AP['CPI Score 2013'].mean(),
                           df_AP['CPI Score 2012'].mean() ]

df_regions.loc['Europe & Central Asia'] = [   df_ECA['CPI score 2022'].mean(),
                           df_ECA['CPI score 2021'].mean(),
                           df_ECA['CPI score 2020'].mean(),
                           df_ECA['CPI score 2019'].mean(),
                           df_ECA['CPI score 2018'].mean(),
                           df_ECA['CPI score 2017'].mean(),
                           df_ECA['CPI score 2016'].mean(),
                           df_ECA['CPI score 2015'].mean(),
                           df_ECA['CPI score 2014'].mean(),
                           df_ECA['CPI Score 2013'].mean(),
                           df_ECA['CPI Score 2012'].mean() ]

df_regions.loc['Middle East'] = [ df_MENA['CPI score 2022'].mean(),
                           df_MENA['CPI score 2021'].mean(),
                           df_MENA['CPI score 2020'].mean(),
                           df_MENA['CPI score 2019'].mean(),
                           df_MENA['CPI score 2018'].mean(),
                           df_MENA['CPI score 2017'].mean(),
                           df_MENA['CPI score 2016'].mean(),
                           df_MENA['CPI score 2015'].mean(),
                           df_MENA['CPI score 2014'].mean(),
                           df_MENA['CPI Score 2013'].mean(),
                           df_MENA['CPI Score 2012'].mean() ]

df_regions.loc['Sub-Saharan Africa'] = [  df_SSA['CPI score 2022'].mean(),
                           df_SSA['CPI score 2021'].mean(),
                           df_SSA['CPI score 2020'].mean(),
                           df_SSA['CPI score 2019'].mean(),
                           df_SSA['CPI score 2018'].mean(),
                           df_SSA['CPI score 2017'].mean(),
                           df_SSA['CPI score 2016'].mean(),
                           df_SSA['CPI score 2015'].mean(),
                           df_SSA['CPI score 2014'].mean(),
                           df_SSA['CPI Score 2013'].mean(),
                           df_SSA['CPI Score 2012'].mean() ]

df_regions.loc['Americas'] = [  df_AME['CPI score 2022'].mean(),
                           df_AME['CPI score 2021'].mean(),
                           df_AME['CPI score 2020'].mean(),
                           df_AME['CPI score 2019'].mean(),
                           df_AME['CPI score 2018'].mean(),
                           df_AME['CPI score 2017'].mean(),
                           df_AME['CPI score 2016'].mean(),
                           df_AME['CPI score 2015'].mean(),
                           df_AME['CPI score 2014'].mean(),
                           df_AME['CPI Score 2013'].mean(),
                           df_AME['CPI Score 2012'].mean() ]

df_regions.loc['Western Europe'] = [   df_EU['CPI score 2022'].mean(),
                           df_EU['CPI score 2021'].mean(),
                           df_EU['CPI score 2020'].mean(),
                           df_EU['CPI score 2019'].mean(),
                           df_EU['CPI score 2018'].mean(),
                           df_EU['CPI score 2017'].mean(),
                           df_EU['CPI score 2016'].mean(),
                           df_EU['CPI score 2015'].mean(),
                           df_EU['CPI score 2014'].mean(),
                           df_EU['CPI Score 2013'].mean(),
                           df_EU['CPI Score 2012'].mean() ]

# %%
df_regions.head()
# Out:
#                        CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# Asia Pacific                45.129032       45.096774       45.290323
# Europe & Central Asia       35.210526       35.684211       35.947368
# Middle East                 37.500000       38.722222       39.111111
# Sub-Saharan Africa          32.387755       32.510204       32.306122
# Americas                    42.968750       43.125000       43.375000
#
#                        CPI score 2019  CPI score 2018  CPI score 2017  \
# Country
# Asia Pacific                44.870968       44.387097       44.387097
# Europe & Central Asia       34.789474       34.526316       34.473684
# Middle East                 39.000000       38.555556       37.888889
# Sub-Saharan Africa          32.244898       32.244898       32.020408
# Americas                    43.375000       43.718750       44.187500
#
#                        CPI score 2016  CPI score 2015  CPI score 2014  \
# Country
# ...

# %%
# Plot average scores for each region

dfT_regions = df_regions.transpose()

USA = '#0027A5'     # Flag Blue
UK =  '#6B7477'     # British Dark Admiralty Grey
Rus = '#FF2400'     # Scarlet
Fr =  '#318CE7'     # French Blue
PRC = '#FFB200'     # Chinese Yellow

plt.figure(figsize=(18,10))

sns.lineplot(data=dfT_regions,linewidth=4,palette=[PRC,'darkviolet','sienna','forestgreen',USA,Fr],
             linestyle='solid',dashes=False).set(title='Corruption Perception Index - Regional Averages')

plt.legend(ncols=6,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## Average CPI by region -- using groupby method

# %%
#  Using groupby

x = pd.DataFrame(dfR_CPI.groupby('Region')[['CPI score 2022','CPI score 2021','CPI score 2020','CPI score 2019','CPI score 2018','CPI score 2017',
                           'CPI score 2016','CPI score 2015','CPI score 2014','CPI Score 2013','CPI Score 2012']].mean())

# %%
display(x)
# Out:
#         CPI score 2022  CPI score 2021  CPI score 2020  CPI score 2019  \
# Region
# AME          42.968750       43.125000       43.375000       43.375000
# AP           45.129032       45.096774       45.290323       44.870968
# ECA          35.210526       35.684211       35.947368       34.789474
# MENA         37.500000       38.722222       39.111111       39.000000
# SSA          32.387755       32.510204       32.306122       32.244898
# WE/EU        65.516129       65.870968       65.806452       66.064516
#
#         CPI score 2018  CPI score 2017  CPI score 2016  CPI score 2015  \
# Region
# AME          43.718750       44.187500       44.093750       40.307692
# AP           44.387097       44.387097       43.866667       42.555556
# ECA          34.526316       34.473684       34.315789       33.210526
# MENA         38.555556       37.888889       37.500000       40.055556
# SSA          32.244898       32.020408       31.456522       32.297872
# ...

# %%
xT_regions = x.transpose()

UK =  '#6B7477'     # British Dark Admiralty Grey
Rus = '#FF2400'     # Scarlet
Fr =  '#318CE7'     # French Blue
PRC = '#FFB200'     # Chinese Yellow

plt.figure(figsize=(18,8))

sns.lineplot(data=xT_regions,linewidth=4,palette=[USA,PRC,'darkviolet','sienna','forestgreen',Fr],
             linestyle='solid',dashes=False).set(title='Corruption Perception Index - Regional Averages')

plt.legend(ncols=6,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## Variance

# %%
display(df_CPI.loc['Fiji',:])   # Fiji is missing most CPI scores -- so we'll delete it later
# Out:
# CPI score 2022    53.0
# CPI score 2021    55.0
# CPI score 2020     NaN
# CPI score 2019     NaN
# CPI score 2018     NaN
# CPI score 2017     NaN
# CPI score 2016     NaN
# CPI score 2015     NaN
# CPI score 2014     NaN
# CPI Score 2013     NaN
# CPI Score 2012     NaN
# Name: Fiji, dtype: float64

# %%
display(df_CPI)
# Out:
#                       CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# Afghanistan                     24.0            16.0            19.0
# Albania                         36.0            35.0            36.0
# United Arab Emirates            67.0            69.0            71.0
# Angola                          33.0            29.0            27.0
# Argentina                       38.0            38.0            42.0
# ...                              ...             ...             ...
# Venezuela                       14.0            14.0            15.0
# Vietnam                         42.0            39.0            36.0
# Syria                           13.0            13.0            14.0
# Zambia                          33.0            33.0            33.0
# Zimbabwe                        23.0            23.0            24.0
#
#                       CPI score 2019  CPI score 2018  CPI score 2017  \
# Country
# ...

# %%
#  Calculate variance -- after managing NaN CPI score values

import numpy as np
import statistics as stat
import scipy.stats as sci


df_CPI['variance'] = 0         # Create 'variance' column

df_CPI = df_CPI.fillna(0)      # Temprorarily assign 0 to NaN values

for R in range(0,len(df_CPI)):

  for C in range(0,11):
    if df_CPI.iloc[R,C] == 0 :
       df_CPI.iloc[R,C] = stat.mean(df_CPI.iloc[R,0:11]) * 1.1

  df_CPI.iloc[R,11] = stat.variance(df_CPI.iloc[R,0:11])


df_CPI.head(20)
# Out:
#                         CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# Afghanistan                       24.0            16.0            19.0
# Albania                           36.0            35.0            36.0
# United Arab Emirates              67.0            69.0            71.0
# Angola                            33.0            29.0            27.0
# Argentina                         38.0            38.0            42.0
# Armenia                           46.0            49.0            49.0
# Australia                         75.0            73.0            77.0
# Austria                           71.0            74.0            76.0
# Azerbaijan                        23.0            30.0            30.0
# Bahamas                           64.0            64.0            63.0
# Israel                            63.0            59.0            60.0
# Bangladesh                        25.0            26.0            26.0
# ...

# %%
# Sort by variance, copy highest values

df_CPI_sorted = df_CPI.sort_values(by=['variance'],ascending=False)

df_sorted = df_CPI_sorted.head(8)

df_sorted.drop(['Fiji'],inplace=True)    # too many missing values

df_CPI_sorted.head(8)

del df_CPI['variance']            # No longer needed

# %%
# Plot countries with highest CPI variance

del df_sorted['variance']         # No longer needed

sortedT = df_sorted.transpose()

plt.figure(figsize=(18,10))

sns.lineplot(data=sortedT,linewidth=4,dashes=False,palette=['slateblue','orange','salmon','deepskyblue','seagreen','brown','fuchsia'],
             linestyle='solid').set(title='Corruption Perception Index - Greatest Variance')

plt.legend(ncols=4,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## BRICS

# %%
# Take a subset of CPI scores for BRICS countries

BRICS = ['Brazil','Russia','India','China','South Africa']

df = df_CPI.loc[BRICS]

df.head()
# Out:
#               CPI score 2022  CPI score 2021  CPI score 2020  CPI score 2019  \
# Country
# Brazil                  38.0            38.0            38.0            35.0
# Russia                  28.0            29.0            30.0            28.0
# India                   40.0            40.0            40.0            41.0
# China                   45.0            45.0            42.0            41.0
# South Africa            43.0            44.0            44.0            44.0
#
#               CPI score 2018  CPI score 2017  CPI score 2016  CPI score 2015  \
# Country
# Brazil                  35.0            37.0            40.0            38.0
# Russia                  28.0            29.0            29.0            29.0
# India                   41.0            40.0            40.0            38.0
# China                   39.0            41.0            40.0            37.0
# South Africa            43.0            43.0            45.0            44.0
#
# ...

# %%
# Plot BRICS countries

dfT = df.transpose()

Bra   =   'lime'
India = 'indianred'
SA    = 'forestgreen'

plt.figure(figsize=(18,10))

sns.lineplot(data=dfT,linewidth=4,palette=['lime',Rus,'indianred',PRC,'forestgreen'],
             linestyle='solid',dashes=False).set(title='Corruption Perception Index - BRICS Countries')

plt.legend(ncols=5,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## "FiveEyes" Countries

# %%
Five_Eyes = ['United States of America','Canada','United Kingdom','Australia','New Zealand']

df = df_CPI.loc[Five_Eyes]

df.head()
# Out:
#                           CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# United States of America            69.0            67.0            67.0
# Canada                              74.0            74.0            77.0
# United Kingdom                      73.0            78.0            77.0
# Australia                           75.0            73.0            77.0
# New Zealand                         87.0            88.0            88.0
#
#                           CPI score 2019  CPI score 2018  CPI score 2017  \
# Country
# United States of America            69.0            71.0            75.0
# Canada                              77.0            81.0            82.0
# United Kingdom                      77.0            80.0            82.0
# Australia                           77.0            77.0            77.0
# New Zealand                         87.0            87.0            89.0
#
# ...

# %%
dfT = df.transpose()

Can = 'crimson'
Aus = 'darkmagenta'
NZ  = 'turquoise'

plt.figure(figsize=(18,10))

sns.lineplot(data=dfT,linewidth=4,palette=[USA,Can,UK,Aus,NZ],
             linestyle='solid',dashes=False).set(title='Corruption Perception Index - "Five Eyes" Countries')

plt.legend(ncols=5,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## BRICS and Five Eyes

# %%
df = df_CPI.loc[Five_Eyes+BRICS]

df.head(12)
# Out:
#                           CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# United States of America            69.0            67.0            67.0
# Canada                              74.0            74.0            77.0
# United Kingdom                      73.0            78.0            77.0
# Australia                           75.0            73.0            77.0
# New Zealand                         87.0            88.0            88.0
# Brazil                              38.0            38.0            38.0
# Russia                              28.0            29.0            30.0
# India                               40.0            40.0            40.0
# China                               45.0            45.0            42.0
# South Africa                        43.0            44.0            44.0
#
#                           CPI score 2019  CPI score 2018  CPI score 2017  \
# Country
# ...

# %%
dfT = df.transpose()

plt.figure(figsize=(18,10))

sns.lineplot(data=dfT,linewidth=4,dashes=False,palette=[USA,Can,UK,Aus,NZ,Bra,Rus,India,PRC,SA],
             linestyle='solid').set(title='Corruption Perception Index - BRICS and "Five Eyes" Countries')

plt.legend(ncols=5,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## Hot Spots

# %%
Hot = ['Russia','Ukraine','Belarus','Moldova','Yemen']

df = df_CPI.loc[Hot]

df.head(12)

dfT = df.transpose()

plt.figure(figsize=(18,10))

sns.lineplot(data=dfT,linewidth=4,dashes=False,palette=[Rus,'m','seagreen','darkred','goldenrod'],
             linestyle='solid').set(title='Corruption Perception Index - Hot Spots')

plt.legend(ncols=5,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## UN Security Council - Permanent Members

# %%
UN = ['United States of America','Russia','China','France','United Kingdom']

UK =  '#6B7477'     # British Dark Admiralty Grey
Rus = '#FF2400'     # Scarlet
Fr =  '#318CE7'     # French Blue
PRC = '#FFB200'     # Chinese Yellow

df = df_CPI.loc[UN]

df.head(12)

dfT = df.transpose()

plt.figure(figsize=(18,10))

sns.lineplot(data=dfT,linewidth=4,palette=[USA,Rus,PRC,Fr,UK],
             linestyle='solid',dashes=False).set(title='Corruption Perception Index - UN Security Council')

plt.legend(ncols=5,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ##  G7 + Russia

# %%
G8 = ['United States of America','Russia','France','United Kingdom','Japan','Italy','Germany','Canada']

Japan = '#FCC9B9'                   # Cherry Blosom                       '#FF4E20'           # Otan
It    = '#007A33'                   # Italian flag (fern) green
Gr    = '#060607'                   # Coal Black
Can   = 'crimson'                   # 'crimson'

df = df_CPI.loc[G8]

df.head(12)

dfT = df.transpose()

plt.figure(figsize=(18,10))

sns.lineplot(data=dfT,linewidth=4,palette=[USA,Rus,Fr,UK,Japan,It,Gr,Can],                                                          #  markers=True,
             linestyle='solid',dashes=False).set(title='Corruption Perception Index - G7 + Russia')

plt.legend(ncols=5,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()

# %% [markdown]
# ## Variance, again -- Let's try this a different way

# %%
df_CPI.describe()
# Out:
#        CPI score 2022  CPI score 2021  CPI score 2020  CPI score 2019  \
# count      181.000000      181.000000      181.000000      181.000000
# mean        42.971271       43.281657       43.164641       42.993812
# std         18.609629       18.729436       18.977462       19.050000
# min         12.000000       11.000000       10.800000        9.000000
# 25%         30.000000       30.000000       29.000000       29.000000
# 50%         40.000000       39.000000       40.000000       39.000000
# 75%         55.000000       55.000000       56.000000       56.000000
# max         90.000000       88.000000       88.000000       87.000000
#
#        CPI score 2018  CPI score 2017  CPI score 2016  CPI score 2015  \
# count      181.000000      181.000000      181.000000      181.000000
# mean        42.950652       42.913673       42.594543       42.584041
# std         19.218984       19.117917       19.490265       20.042046
# ...

# %%
# Get list of columns

scores = df_CPI.columns

print( df_CPI.columns )

L = [ x for x in df_CPI.columns ]

print( L )

type(L)
# Out:
# Index(['CPI score 2022', 'CPI score 2021', 'CPI score 2020', 'CPI score 2019',
#        'CPI score 2018', 'CPI score 2017', 'CPI score 2016', 'CPI score 2015',
#        'CPI score 2014', 'CPI Score 2013', 'CPI Score 2012'],
#       dtype='object')
# ['CPI score 2022', 'CPI score 2021', 'CPI score 2020', 'CPI score 2019', 'CPI score 2018', 'CPI score 2017', 'CPI score 2016', 'CPI score 2015', 'CPI score 2014', 'CPI Score 2013', 'CPI Score 2012']
# list

# %%
import numpy as np

df_CPI = df_CPI.fillna(0)

df_CPI['variance'] = np.var( df_CPI[L] )  # Creates a variance column which will be needed, but np.var won't work on rows

display( df_CPI )
# Out:
#                       CPI score 2022  CPI score 2021  CPI score 2020  \
# Country
# Afghanistan                     24.0            16.0            19.0
# Albania                         36.0            35.0            36.0
# United Arab Emirates            67.0            69.0            71.0
# Angola                          33.0            29.0            27.0
# Argentina                       38.0            38.0            42.0
# ...                              ...             ...             ...
# Venezuela                       14.0            14.0            15.0
# Vietnam                         42.0            39.0            36.0
# Syria                           13.0            13.0            14.0
# Zambia                          33.0            33.0            33.0
# Zimbabwe                        23.0            23.0            24.0
#
#                       CPI score 2019  CPI score 2018  CPI score 2017  \
# Country
# ...

# %% [markdown]
# ## Transposing to find Variance

# %%
# Find variances by transposing and using var() funcion on columns instead of rows.

df_CPI.T.columns

NR = df_CPI.T.var()

display(NR)
type(NR)
# Out:
# Country
# Afghanistan             22.072727
# Albania                  5.218182
# United Arab Emirates     2.818182
# Angola                  29.818182
# Argentina               14.872727
#                           ...
# Venezuela                4.200000
# Vietnam                 13.872727
# Syria                   17.363636
# Zambia                   4.963636
# Zimbabwe                 1.690909
# Length: 181, dtype: float64
# pandas.core.series.Series

# %%
#  You need to have ['variance'] already defined before you can add data too it!

df_CPI.T.loc['variance'] = NR

# %%
# print( df_CPI.T.loc['variance'] )

display(NR)
# Out:
# Country
# Afghanistan             22.072727
# Albania                  5.218182
# United Arab Emirates     2.818182
# Angola                  29.818182
# Argentina               14.872727
#                           ...
# Venezuela                4.200000
# Vietnam                 13.872727
# Syria                   17.363636
# Zambia                   4.963636
# Zimbabwe                 1.690909
# Length: 181, dtype: float64

# %%
df_CPI.T.tail()
# Out:
# Country         Afghanistan    Albania  United Arab Emirates     Angola  \
# CPI score 2015    11.000000  36.000000             70.000000  15.000000
# CPI score 2014    12.000000  33.000000             70.000000  19.000000
# CPI Score 2013     8.000000  31.000000             69.000000  23.000000
# CPI Score 2012     8.000000  33.000000             68.000000  22.000000
# variance          22.072727   5.218182              2.818182  29.818182
#
# Country         Argentina    Armenia  Australia    Austria  Azerbaijan  \
# CPI score 2015  32.000000  35.000000  79.000000  76.000000   29.000000
# CPI score 2014  34.000000  37.000000  80.000000  72.000000   29.000000
# CPI Score 2013  34.000000  36.000000  81.000000  69.000000   28.000000
# CPI Score 2012  35.000000  34.000000  85.000000  69.000000   27.000000
# variance        14.872727  37.963636  10.163636   8.454545    6.054545
#
# Country         Bahamas  ...  United Kingdom  United States of America  \
# ...

# %%
#  Another plot of high variance countries

df_CPI_sorted = df_CPI.sort_values(by=['variance'],ascending=False)

df_sorted = df_CPI_sorted.head(8)

df_sorted.drop(['Fiji'],inplace=True)    # too many missing values

df_CPI_sorted.head(8)

del df_CPI['variance']

del df_sorted['variance']

sortedT = df_sorted.transpose()

plt.figure(figsize=(18,10))

sns.lineplot(data=sortedT,linewidth=4,dashes=False,palette=['slateblue','orange','salmon','deepskyblue','seagreen','brown','fuchsia'],
             linestyle='solid').set(title='Corruption Perception Index - Greatest Variance')

plt.legend(ncols=4,fontsize='medium',bbox_to_anchor=(0.75,-0.06))

plt.show()
